# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %% [markdown]
# # Tasks

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Task (2) Dataset.csv')

# %%
df.isna().sum()
# Out:
# City                      0
# Datetime                  0
# TrafficIndexLive          0
# JamsCount                 0
# JamsDelay                 0
# JamsLength                0
# TrafficIndexWeekAgo       0
# TravelTimeHistoric     3867
# TravelTimeLive         3867
# dtype: int64

# %%
df['TravelTimeHistoric']=df['TravelTimeHistoric'].mean()

# %%
df['TravelTimeLive']=df['TravelTimeLive'].mean()

# %%
df['TravelTimeLive']
# Out:
# 0        70.048451
# 1        70.048451
# 2        70.048451
# 3        70.048451
# 4        70.048451
#            ...
# 66634    70.048451
# 66635    70.048451
# 66636    70.048451
# 66637    70.048451
# 66638    70.048451
# Name: TravelTimeLive, Length: 66639, dtype: float64

# %%
df.isna().sum()
# Out:
# City                   0
# Datetime               0
# TrafficIndexLive       0
# JamsCount              0
# JamsDelay              0
# JamsLength             0
# TrafficIndexWeekAgo    0
# TravelTimeHistoric     0
# TravelTimeLive         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  datetime64[ns]
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   66639 non-null  float64
#  8   TravelTimeLive       66639 non-null  float64
#  9   Date                 66639 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(2)
# memory usage: 5.1+ MB

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.head()
# Out:
#        City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0  Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1  Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2  Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3  Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4  Abudhabi  2023-07-07 12:01:30                 8         20       62.1
#
#    JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# 0         0.7                   13           70.706601       70.048451
# 1         1.7                    8           70.706601       70.048451
# 2         2.8                    6           70.706601       70.048451
# 3         5.5                    6           70.706601       70.048451
# 4         6.5                    5           70.706601       70.048451

# %%
df.describe()
# Out:
#        TrafficIndexLive     JamsCount     JamsDelay    JamsLength  \
# count      66639.000000  66639.000000  66639.000000  66639.000000
# mean          14.043113     74.278531    288.353877     49.316135
# std           13.488906    107.452022    470.013224     85.352525
# min            0.000000      0.000000      0.000000      0.000000
# 25%            3.000000      9.000000     27.700000      3.000000
# 50%           10.000000     29.000000     95.700000     12.200000
# 75%           21.000000     95.000000    336.600000     53.500000
# max          138.000000   1359.000000   9989.400000   1173.900000
#
#        TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# count         66639.000000        66639.000000    66639.000000
# mean             13.981737           70.706601       70.048451
# std              13.454922            0.000000        0.000000
# min               0.000000           70.706601       70.048451
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  datetime64[ns]
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   66639 non-null  float64
#  8   TravelTimeLive       66639 non-null  float64
#  9   Date                 66639 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(2)
# memory usage: 5.1+ MB

# %%
num_col=df[['TrafficIndexLive','JamsCount']]
num_col.plot.scatter(x='TrafficIndexLive', y='JamsCount')

# %%
numerical_col=df[['TrafficIndexLive','JamsCount']]
numerical_col.plot.scatter(x='TrafficIndexLive', y='JamsCount')
# Out:
# <Axes: xlabel='TrafficIndexLive', ylabel='JamsCount'>

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  object
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   66639 non-null  float64
#  8   TravelTimeLive       66639 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 4.6+ MB

# %%
df['Datetime']
# Out:
# 0        2023-07-07 08:01:30
# 1        2023-07-07 09:01:30
# 2        2023-07-07 10:46:30
# 3        2023-07-07 11:16:30
# 4        2023-07-07 12:01:30
#                 ...
# 66634    2023-12-15 03:01:30
# 66635    2023-12-15 04:31:30
# 66636    2023-12-15 05:01:30
# 66637    2023-12-15 06:01:30
# 66638    2023-12-15 07:01:30
# Name: Datetime, Length: 66639, dtype: object

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['TrafficIndexLive'], bins=20, kde=True)
plt.xlabel('Traffic Index Live')
plt.ylabel('counts')
plt.show()


df['Datetime'] = pd.to_datetime(df['Datetime'])
df['Date'] = df['Datetime'].dt.date


plt.figure(figsize=(8, 6))
sns.lineplot(x='Date', y='TrafficIndexLive', data=df)
plt.xlabel('Date')
plt.ylabel('TrafficIndexLive')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %%
df['Weather_Condition']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Weather_Condition'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
f=(df.loc[: , ['TrafficIndexLive','Datetime','TrafficIndexWeekAgo']]).corr()
sns.heatmap(f,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  datetime64[ns]
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   66639 non-null  float64
#  8   TravelTimeLive       66639 non-null  float64
#  9   Date                 66639 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(2)
# memory usage: 5.1+ MB

# %%
f=(df.loc[: , ['TrafficIndexLive','Datetime','TrafficIndexWeekAgo','JamsCount','TravelTimeLive','TravelTimeHistoric','JamsLength','JamsDelay']]).corr()
sns.heatmap(f,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# Summary:
# the relations between entities are increasing
